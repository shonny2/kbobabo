# %%
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://statiz.sporki.com/stats/?m=main&m2=pitching&m3=default&so=WAR&ob=DESC&year=2023&sy=&ey=&te=&po=&lt=10100&reg=A&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2='

response = requests.get(url)

# %%
html = response.text
soup = BeautifulSoup(html, 'html.parser')
temp = soup.find_all("table")[0]

# %%
df = pd.DataFrame(index = range(50), columns = ["Rank", "Name", "Team", "WAR", "G", "GS", "GR", "GF", "W", "L", "S", "HD", "IP", "ER",
                                                 "R", "rRA", "TBF", "H", "2B", "3B", "HR", "BB", "HP", "IB", "SO", "ROE",
                                                 "BK", "WP", "ERA", "RA9", "rRA9", "rRA9pf", "FIP", "WHIP", "WAR"])

df

# %%
l = 0
trs = temp.find_all("tr")
for j in range(2, min(414, len(trs))):  # 리스트의 길이를 벗어나지 않도록 조정
    temp2 = trs[j]
    if len(temp2.find_all("td")) == 35:
        for i in range(35):
            tds = temp2.find_all("td")
            if i < len(tds):  # 리스트의 길이를 벗어나지 않도록 조정
                temp3 = tds[i]
                df.iloc[l,i] = temp3.get_text()
            else:
                # 만약 인덱스가 범위를 벗어난 경우 처리할 내용 추가
                pass
        l += 1

df
# Out:
#    Rank   Name   Team   WAR   G  GS  GR  GF   W   L  ... ROE BK  WP   ERA  \
# 0     1     페디  23  P  7.95  30  30   0   0  20   6  ...  13  0   5  2.00
# 1     2    후라도  23  P  7.12  30  30   0   0  11   8  ...  15  0   5  2.65
# 2     3    안우진  23  P  6.86  24  24   0   0   9   7  ...   5  0   8  2.39
# 3     4    뷰캐넌  23  P  6.31  30  30   0   1  12   8  ...  13  1   7  2.54
# 4     5    고영표  23  P  5.91  28  27   1   1  12   7  ...   6  0   6  2.78
# 5     6   알칸타라  23  P  5.79  31  31   0   0  13   9  ...  11  0   3  2.67
# 6     7     반즈  23  P  5.74  30  30   0   0  11  10  ...   7  0   7  3.28
# 7     8    박세웅  23  P  4.63  27  27   0   0   9   7  ...   9  0  10  3.45
# 8     9    플럿코  23  P  4.58  21  21   0   0  11   3  ...   6  0   2  2.41
# 9    10   쿠에바스  23  P  4.57  18  18   0   0  12   0  ...   2  0   5  2.60
# 10   11    김광현  23  P  4.48  30  30   0   0   9   8  ...   9  0   5  3.53
# 11   12    원태인  23  P  4.48  26  26   0   0   7   7  ...   4  2   6  3.24
# ...
