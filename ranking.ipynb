# %%
import json
import unicodedata
import urllib.request
from bs4 import BeautifulSoup
 
def preformat_cjk (string, width, align='<', fill=' '):
        count = (width - sum(1 + (unicodedata.east_asian_width(c) in "WF") for c in string))
        return {
                '>': lambda s: fill * count + s,
                '<': lambda s: s + fill * count,
                '^': lambda s: fill * (count / 2)
                                + s
                                + fill * (count / 2 + count % 2)
}[align](string)
 
baseballData = urllib.request.urlopen('https://sports.news.naver.com/kbaseball/record/index?category=kbo&year=2021')
source = baseballData.read()
baseballData.close()
 
soup = BeautifulSoup(source,'html.parser')
soup = soup.find_all('script')
 
for script in soup:
  line = str(script)
 
  if 'var ' in line and 'jsonTeamRecord' in line:
    recordList = line.split('jsonTeamRecord = ')
 
    for record in recordList:
      if record.startswith('{'):
        recordLine = record.splitlines()
        for finalLine in recordLine:
          if finalLine.endswith('}]};'):
            recordJsonData = finalLine
 
 
r = json.loads(recordJsonData[:-1])
regularTeamRecordList = r['regularTeamRecordList']
 
order=0
for team in regularTeamRecordList:
  t = json.loads(str(team).replace("'",'"'))
  order += 1
  tn = preformat_cjk(t['teamName'], 10)
  won = t['won']
  lost = t['lost']
  winDiff = t['winDiff']
  recentResult = t['recentResult']
  print('%02d  %s  %s  %s  %-5s   %s' % (order, tn, won, lost, winDiff, recentResult))
# Out:
# 01  KT          76  59  0       3승-6패-1무
# 02  두산        71  65  5.5     5승-3패-2무
# 03  삼성        76  59  0       6승-3패-1무
# 04  LG          72  58  1.5     3승-2패-5무
# 05  키움        70  67  7       6승-3패-1무
# 06  SSG         66  64  7.5     4승-4패-2무
# 07  NC          67  68  9       4승-5패-1무
# 08  롯데        65  71  11.5    4승-4패-2무
# 09  KIA         58  76  17.5    5승-5패-0무
# 10  한화        49  83  25.5    2승-6패-2무

# %%
import json
import unicodedata
import urllib.request
from bs4 import BeautifulSoup
 
def preformat_cjk (string, width, align='<', fill=' '):
        count = (width - sum(1 + (unicodedata.east_asian_width(c) in "WF") for c in string))
        return {
                '>': lambda s: fill * count + s,
                '<': lambda s: s + fill * count,
                '^': lambda s: fill * (count / 2)
                                + s
                                + fill * (count / 2 + count % 2)
}[align](string)
 
baseballData = urllib.request.urlopen('https://sports.news.naver.com/kbaseball/record/index?category=kbo&year=2022')
source = baseballData.read()
baseballData.close()
 
soup = BeautifulSoup(source,'html.parser')
soup = soup.find_all('script')
 
for script in soup:
  line = str(script)
 
  if 'var ' in line and 'jsonTeamRecord' in line:
    recordList = line.split('jsonTeamRecord = ')
 
    for record in recordList:
      if record.startswith('{'):
        recordLine = record.splitlines()
        for finalLine in recordLine:
          if finalLine.endswith('}]};'):
            recordJsonData = finalLine
 
 
r = json.loads(recordJsonData[:-1])
regularTeamRecordList = r['regularTeamRecordList']
 
order=0
for team in regularTeamRecordList:
  t = json.loads(str(team).replace("'",'"'))
  order += 1
  tn = preformat_cjk(t['teamName'], 10)
  won = t['won']
  lost = t['lost']
  winDiff = t['winDiff']
  recentResult = t['recentResult']
  print('%02d  %s  %s  %s  %-5s   %s' % (order, tn, won, lost, winDiff, recentResult))
# Out:
# 01  SSG         88  52  0       4승-6패-0무
# 02  키움        80  62  9       5승-5패-0무
# 03  LG          87  55  2       4승-6패-0무
# 04  KT          80  62  9       7승-3패-0무
# 05  KIA         70  73  19.5    7승-3패-0무
# 06  NC          67  74  21.5    6승-4패-0무
# 07  삼성        66  76  23      6승-4패-0무
# 08  롯데        64  76  24      5승-5패-0무
# 09  두산        60  82  29      4승-6패-0무
# 10  한화        46  96  43      3승-7패-0무

# %%
import json
import unicodedata
import urllib.request
from bs4 import BeautifulSoup
 
def preformat_cjk (string, width, align='<', fill=' '):
        count = (width - sum(1 + (unicodedata.east_asian_width(c) in "WF") for c in string))
        return {
                '>': lambda s: fill * count + s,
                '<': lambda s: s + fill * count,
                '^': lambda s: fill * (count / 2)
                                + s
                                + fill * (count / 2 + count % 2)
}[align](string)
 
baseballData = urllib.request.urlopen('https://sports.news.naver.com/kbaseball/record/index?category=kbo&year=2023')
source = baseballData.read()
baseballData.close()
 
soup = BeautifulSoup(source,'html.parser')
soup = soup.find_all('script')
 
for script in soup:
  line = str(script)
 
  if 'var ' in line and 'jsonTeamRecord' in line:
    recordList = line.split('jsonTeamRecord = ')
 
    for record in recordList:
      if record.startswith('{'):
        recordLine = record.splitlines()
        for finalLine in recordLine:
          if finalLine.endswith('}]};'):
            recordJsonData = finalLine
 
 
r = json.loads(recordJsonData[:-1])
regularTeamRecordList = r['regularTeamRecordList']
 
order=0
for team in regularTeamRecordList:
  t = json.loads(str(team).replace("'",'"'))
  order += 1
  tn = preformat_cjk(t['teamName'], 10)
  won = t['won']
  lost = t['lost']
  winDiff = t['winDiff']
  recentResult = t['recentResult']
  print('%02d  %s  %s  %s  %-5s   %s' % (order, tn, won, lost, winDiff, recentResult))
# Out:
# 01  LG          86  56  0       5승-5패-0무
# 02  KT          79  62  6.5     6승-4패-0무
# 03  SSG         76  65  9.5     8승-2패-0무
# 04  NC          75  67  11      5승-5패-0무
# 05  두산        74  68  12      4승-6패-0무
# 06  KIA         73  69  13      7승-3패-0무
# 07  롯데        68  76  19      4승-6패-0무
# 08  삼성        61  82  25.5    4승-6패-0무
# 09  한화        58  80  26      3승-7패-0무
# 10  키움        58  83  27.5    5승-5패-0무
